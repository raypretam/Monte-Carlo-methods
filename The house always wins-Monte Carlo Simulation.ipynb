# %% [markdown]
# How do casinos earn money? The trick is simple- you play long enough, the probability of losing money increases. Let us take a look at how this works with a simple Monte Carlo simulation.

# %% [markdown]
# Let’s suppose Jack bets $1 on this game.
#
# Probability of Jack winning = 49/100
#
# Probability of the casino winning = 51/100
#
# Expected profit for the player= 1*(49/100)-1*(51/100) = -0.02 = -2%

# %%
#import libraries
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Create function for simulating die roll 
#The die can take values from 1 to 100. If the number is between 1 and 51, the house wins. 
#If the number is between 52 and 100, the player wins.

def roll_dice():
    die = random.randint(1,100)
    
    if die <= 51:
        return False
    elif die >51 and die <=100:
        return True

# %%
#Define a function for the play which takes 3 arguments :
#1. total_funds = total money in hand the player is starting with
#2. wager_amount = the betting amount each time the player plays
#3. total_plays = the number of times the player bets on this game

def play(total_funds,wager_amount,total_plays):
    
    #Create empty lists for :
    # 1.Play_number and 
    # 2.Funds available
    # 3.Final Fund
    play_num = []
    funds = []
    
    play = 1
    while play < total_plays:
        if roll_dice():
            total_funds += wager_amount
        else:
            total_funds -= wager_amount
        
        play += 1
        play_num.append(play)
        funds.append(total_funds)
    
    plt.plot(play_num,funds)
    final_fund.append(funds[-1])
    return final_fund

# %%
#Call the function to simulate the plays and calculate the remaining funds of the player after all the bets

x = 1
final_fund = []
num_play = []
avg_fund = []
while x <= 100:
    ending_fund = play(10000,100,5)
    x += 1

num_play.append(5)
average_ending_fund = str(sum(ending_fund)/len(ending_fund))
avg_fund.append(average_ending_fund)

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print ("The player starts the game with 10000$ and ends with {}$".format(average_ending_fund))
# Out:
# The player starts the game with 10000$ and ends with 9972.0$

# %%
#Call the function to simulate the plays and calculate the remaining funds of the player after all the bets

x = 1
final_fund = []
while x <= 100:
    ending_fund = play(10000,100,10)
    x += 1

num_play.append(10)
average_ending_fund = str(sum(ending_fund)/len(ending_fund))
avg_fund.append(average_ending_fund)

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print ("The player starts the game with 10000$ and ends with {}$".format(str(sum(ending_fund)/len(ending_fund))))
# Out:
# The player starts the game with 10000$ and ends with 9968.0$

# %%
#Call the function to simulate the plays and calculate the remaining funds of the player after all the bets

x = 1
final_fund = []
while x <= 100:
    ending_fund = play(10000,100,50)
    x += 1

num_play.append(50)
average_ending_fund = str(sum(ending_fund)/len(ending_fund))
avg_fund.append(average_ending_fund)

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print ("The player starts the game with 10000$ and ends with {}$".format(str(sum(ending_fund)/len(ending_fund))))
# Out:
# The player starts the game with 10000$ and ends with 9964.0$

# %%
#Call the function to simulate the plays and calculate the remaining funds of the player after all the bets

x = 1
final_fund = []
while x <= 100:
    ending_fund = play(10000,100,100)
    x += 1

num_play.append(100)
average_ending_fund = str(sum(ending_fund)/len(ending_fund))
avg_fund.append(average_ending_fund)

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print ("The player starts the game with 10000$ and ends with {}$".format(str(sum(ending_fund)/len(ending_fund))))
# Out:
# The player starts the game with 10000$ and ends with 9942.0$

# %%
#Call the function to simulate the plays and calculate the remaining funds of the player after all the bets

x = 1
final_fund = []
while x <= 100:
    ending_fund = play(10000,100,500)
    x += 1

num_play.append(500)
average_ending_fund = str(sum(ending_fund)/len(ending_fund))
avg_fund.append(average_ending_fund)

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print ("The player starts the game with 10000$ and ends with {}$".format(str(sum(ending_fund)/len(ending_fund))))
# Out:
# The player starts the game with 10000$ and ends with 8832.0$

# %%
#Call the function to simulate the plays and calculate the remaining funds of the player after all the bets

x = 1
final_fund = []
while x <= 100:
    ending_fund = play(10000,100,1000)
    x += 1

num_play.append(1000)
average_ending_fund = str(sum(ending_fund)/len(ending_fund))
avg_fund.append(average_ending_fund)

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print ("The player starts the game with 10000$ and ends with {}$".format(str(sum(ending_fund)/len(ending_fund))))
# Out:
# The player starts the game with 10000$ and ends with 7890.0$

# %%
#Call the function to simulate the plays and calculate the remaining funds of the player after all the bets

x = 1
final_fund = []
while x <= 100:
    ending_fund = play(10000,100,5000)
    x += 1

num_play.append(1000)
average_ending_fund = str(sum(ending_fund)/len(ending_fund))
avg_fund.append(average_ending_fund)

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print ("The player starts the game with 10000$ and ends with {}$".format(str(sum(ending_fund)/len(ending_fund))))
# Out:
# The player starts the game with 10000$ and ends with 744.0$

# %%
#Call the function to simulate the plays and calculate the remaining funds of the player after all the bets

x = 1
final_fund = []
while x <= 100:
    ending_fund = play(10000,100,10000)
    x += 1

num_play.append(10000)
average_ending_fund = str(sum(ending_fund)/len(ending_fund))
avg_fund.append(average_ending_fund)

plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

print ("The player starts the game with 10000$ and ends with {}$".format(str(sum(ending_fund)/len(ending_fund))))
# Out:
# The player starts the game with 10000$ and ends with -10648.0$

# %% [markdown]
# It can also be observed that the amount lost in every scenario is approximately 2% of the betting amount (same as the house edge). For example, in our final scenario — Jack made 10,000 bets, each for 100$.
#
# So we would expect Jack to lose approximately (10,000)*(0.02*100), which amounts to 20,000$.
#
# Moreover, in the last scenario when he plays 10,000 times, the funds have become negative, i.e Jack has lost more money than what he started with (In real life, it means Jack lost all his money).
# #### THE HOUSE ALWAYS WINS !
